# %% [markdown]
# # WorldExplorer — China
# ### Scripting Take-Home Exam — June 2026
# A smart travel guide for China. Fill in your profile and get personalised destination recommendations, maps, climate analysis and more.

# %%
#Profile

from WorldExplorer.traveller_profile import traveller_profile

profile = traveller_profile()
# Out:
# 🌏 WorldExplorer - China
# Let's figure out where you should go!
#
#
# What's your budget?
#   1. Backpacker  (under €30/night)
#   2. Mid-range   (€30 – €100/night)
#   3. Luxury      (over €100/night)
#
# When are you planning to go?
#   1. January
#   2. February
#   3. March
#   4. April
#   5. May
#   6. June
#   7. July
#   8. August
#   9. September
#   10. October
#   11. November
#   12. December
#
# What kind of traveller are you? (pick one or more)
#   1. Sun & Sea
#   2. Adventure
#   3. Culture & History
#   4. Nature & Wildlife
#   5. Citytrip
#   6. Gastronomy
#   7. Wellness & Spa
#   8. Backpacker/Budget
#
# Who are you going with?
#   1. Solo
#   2. Couple
#   3. Family with kids
#   4. Friend group
#
# How do you want to get around?
#   1. Public transport
#   2. Rent a car
#   3. Cycling
#
# Alright, here's your profile:
#   budget: luxury
#   travel_months: ['July']
#   days: 21
#   interests: ['culture_history', 'citytrip']
#   company: solo
#   mobility: public_transport

# %%
#Match Destinations

from WorldExplorer.match_destinations import match_destinations

df = match_destinations(profile)
df
# Out:
# finding your best matches...
# generating motivations...
# results saved to data/top5_destinations.csv
#
# ==================================================
# your top 5 destinations in China
# ==================================================
#
# 1. Beijing — 83/100
#    airport: PEK (25 km away)
#    avg cost per night: €80
#    Beijing is an absolute must-visit for any culture and history enthusiast, with its breathtaking Forbidden City and stunning Temple of Heaven. As a solo traveler with a luxury budget, you'll love exploring this vibrant city's high-end amenities and immerging yourself in its rich heritage. July is a great time to experience Beijing's electric atmosphere, making it an unforgettable city trip.
#    score breakdown:
#      interests: 40/40 - matches: citytrip, culture_history
#      budget: 10/20 - close match
#      climate: 25/25 - great temp (26.1°C)
#      company: 8/15 - ok for solo
#
# 2. Shanghai — 68/100
#    airport: PVG (30 km away)
#    avg cost per night: €120
#    Shanghai is an amazing match for you, offering a unique blend of traditional Chinese culture and modern city life. As a solo traveler with a luxury budget, you'll love exploring the city's vibrant streets, historic landmarks, and world-class museums in July. From the iconic Bund to the stunning skyline, Shanghai is sure to impress.
#    score breakdown:
#      interests: 20/40 - matches: citytrip
#      budget: 20/20 - perfect match
#      climate: 25/25 - great temp (26.1°C)
#      company: 3/15 - not ideal for solo
#
# 3. Xian — 63/100
#    airport: XIY (47 km away)
#    avg cost per night: €55
#    Xian is an incredible match for you, offering a rich tapestry of culture and history to explore, from the iconic Terracotta Warriors to the ancient city walls. As a solo luxury traveler, you'll love the city's vibrant atmosphere and high-end amenities. With plenty of unique experiences to discover, Xian is sure to leave you in awe this July.
#    score breakdown:
#      interests: 20/40 - matches: culture_history
#      budget: 10/20 - close match
#      climate: 25/25 - great temp (25.8°C)
#      company: 8/15 - ok for solo
#
# 4. Hangzhou — 63/100
#    airport: HGH (30 km away)
#    avg cost per night: €65
#    Hangzhou is an incredible match for you, offering a unique blend of rich cultural heritage and modern city life. You'll love exploring the historic West Lake, a UNESCO World Heritage site, and discovering the city's vibrant temples and museums. With your luxury budget, you can indulge in 5-star comfort and world-class amenities in this stunning city.
#    score breakdown:
#      interests: 20/40 - matches: culture_history
#      budget: 10/20 - close match
#      climate: 25/25 - great temp (26.9°C)
#      company: 8/15 - ok for solo
#
# 5. Tibet — 62/100
#    airport: LXA (62 km away)
#    avg cost per night: €60
#    Tibet is an incredible match for you, with its rich cultural heritage and historic landmarks like the Potala Palace. As a solo traveler, you'll love exploring the vibrant city of Lhasa, immersed in traditional Tibetan culture. With a luxury budget, you can experience the best of Tibet in style this July.
#    score breakdown:
#      interests: 20/40 - matches: culture_history
#      budget: 10/20 - close match
#      climate: 17/25 - ok temp (16.3°C)
#      company: 15/15 - great for solo
#      region  score                                          breakdown  \
# 0   Beijing     83  {'interests': '40/40 - matches: citytrip, cult...
# 1  Shanghai     68  {'interests': '20/40 - matches: citytrip', 'bu...
# 2      Xian     63  {'interests': '20/40 - matches: culture_histor...
# 3  Hangzhou     63  {'interests': '20/40 - matches: culture_histor...
# 4     Tibet     62  {'interests': '20/40 - matches: culture_histor...
#
#                                           motivation  avg_cost_night airport  \
# 0  Beijing is an absolute must-visit for any cult...              80     PEK
# 1  Shanghai is an amazing match for you, offering...             120     PVG
# 2  Xian is an incredible match for you, offering ...              55     XIY
# 3  Hangzhou is an incredible match for you, offer...              65     HGH
# 4  Tibet is an incredible match for you, with its...              60     LXA
#
#    airport_km                                        description
# 0          25  Ancient capital with the Great Wall and Forbid...
# 1          30  Modern megacity with iconic skyline, street fo...
# 2          47  Silk Road city famous for the Terracotta Army ...
# 3          30  West Lake, tea plantations and one of China's ...
# 4          62  The Roof of the World — monasteries, high alti...

# %%
# Attraction map

from WorldExplorer.attractions_map import attractions_map

top5_regions = df["region"].tolist()
print(f"showing map for: {top5_regions}")

m = attractions_map(profile=profile, regions=top5_regions)
m
# Out:
# showing map for: ['Beijing', 'Shanghai', 'Xian', 'Hangzhou', 'Tibet']
#
# building map...
#   getting attractions for Beijing...
#   getting attractions for Shanghai...
#   getting attractions for Xian...
#   getting attractions for Hangzhou...
#   getting attractions for Tibet...
# map saved to data/attractions_map.html
# total markers: 117
#   Culture & History: 97
#   Citytrip: 20
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dcb1e163062c64e82f910f21ea497836 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#         &lt;div style=&quot;position:fixed; top:10px; left:50%; transform:translateX(-50%);
#         z-index:1000; background:white; padding:10px 20px; border-radius:8px;
#         box-shadow:0 2px 6px rgba(0,0,0,0.3); font-family:Arial; font-size:14px; font-weight:bold;&quot;&gt;
#         WorldExplorer — China | culture_history, citytrip
#         &lt;/div&gt;
#
#
#     &lt;div style=&quot;position:fixed; bottom:30px; left:10px; z-index:1000;
#     background:white; padding:12px; border-radius:8px;
#     box-shadow:0 2px 6px rgba(0,0,0,0.3); font-family:Arial; font-size:12px;&quot;&gt;
#         &lt;b&gt;Categories&lt;/b&gt;&lt;br&gt;&lt;br&gt;
#         &lt;div style=&quot;display:flex; align-items:center; margin:4px 0;&quot;&gt;
#             &lt;div style=&quot;width:12px; height:12px; background:blue;
#             border-radius:50%; margin-right:8px;&quot;&gt;&lt;/div&gt;
#             &lt;span&gt;Sun &amp; Sea&lt;/span&gt;
#         &lt;/div&gt;
#
#         &lt;div style=&quot;display:flex; align-items:center; margin:4px 0;&quot;&gt;
#             &lt;div style=&quot;width:12px; height:12px; background:orange;
#             border-radius:50%; margin-right:8px;&quot;&gt;&lt;/div&gt;
#             &lt;span&gt;Adventure&lt;/span&gt;
#         &lt;/div&gt;
#
#         &lt;div style=&quot;display:flex; align-items:center; margin:4px 0;&quot;&gt;
#             &lt;div style=&quot;width:12px; height:12px; background:red;
#             border-radius:50%; margin-right:8px;&quot;&gt;&lt;/div&gt;
#             &lt;span&gt;Culture &amp; History&lt;/span&gt;
#         &lt;/div&gt;
#
#         &lt;div style=&quot;display:flex; align-items:center; margin:4px 0;&quot;&gt;
#             &lt;div style=&quot;width:12px; height:12px; background:green;
#             border-radius:50%; margin-right:8px;&quot;&gt;&lt;/div&gt;
#             &lt;span&gt;Nature &amp; Wildlife&lt;/span&gt;
#         &lt;/div&gt;
#
#         &lt;div style=&quot;display:flex; align-items:center; margin:4px 0;&quot;&gt;
#             &lt;div style=&quot;width:12px; height:12px; background:purple;
#             border-radius:50%; margin-right:8px;&quot;&gt;&lt;/div&gt;
#             &lt;span&gt;Citytrip&lt;/span&gt;
#         &lt;/div&gt;
#
#         &lt;div style=&quot;display:flex; align-items:center; margin:4px 0;&quot;&gt;
#             &lt;div style=&quot;width:12px; height:12px; background:beige;
#             border-radius:50%; margin-right:8px;&quot;&gt;&lt;/div&gt;
#             &lt;span&gt;Gastronomy&lt;/span&gt;
#         &lt;/div&gt;
#
#         &lt;div style=&quot;display:flex; align-items:center; margin:4px 0;&quot;&gt;
#             &lt;div style=&quot;width:12px; height:12px; background:pink;
#             border-radius:50%; margin-right:8px;&quot;&gt;&lt;/div&gt;
#             &lt;span&gt;Wellness &amp; Spa&lt;/span&gt;
#         &lt;/div&gt;
#
#         &lt;div style=&quot;display:flex; align-items:center; margin:4px 0;&quot;&gt;
#             &lt;div style=&quot;width:12px; height:12px; background:gray;
#             border-radius:50%; margin-right:8px;&quot;&gt;&lt;/div&gt;
#             &lt;span&gt;Backpacker/Budget&lt;/span&gt;
#         &lt;/div&gt;
#
#     &lt;/div&gt;
#
#
#     &lt;div style=&quot;position:fixed; top:60px; left:50%; transform:translateX(-50%);
#     z-index:1000; background:white; padding:8px 16px; border-radius:8px;
#     box-shadow:0 2px 6px rgba(0,0,0,0.3); font-family:Arial; font-size:12px;&quot;&gt;
#         &lt;b&gt;Attractions found:&lt;/b&gt;
#         &lt;div style=&quot;display:inline-block; margin:0 10px; text-align:center;&quot;&gt;
#             &lt;div style=&quot;width:10px; height:10px; background:red;
#             border-radius:50%; display:inline-block; margin-right:4px;&quot;&gt;&lt;/div&gt;
#             &lt;b&gt;Culture &amp; History:&lt;/b&gt; 97
#         &lt;/div&gt;
#
#         &lt;div style=&quot;display:inline-block; margin:0 10px; text-align:center;&quot;&gt;
#             &lt;div style=&quot;width:10px; height:10px; background:purple;
#             border-radius:50%; display:inline-block; margin-right:4px;&quot;&gt;&lt;/div&gt;
#             &lt;b&gt;Citytrip:&lt;/b&gt; 20
#         &lt;/div&gt;
#
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dcb1e163062c64e82f910f21ea497836&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dcb1e163062c64e82f910f21ea497836 = L.map(
#                 &quot;map_dcb1e163062c64e82f910f21ea497836&quot;,
#                 {
#                     center: [35.8617, 104.1954],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d56d343989d4a8c9c173e0c7c8024c87 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;:

# %%
# Seasonal analysis

from WorldExplorer.seasonal_analysis import seasonal_analysis
from IPython.display import Image, display

for region_name in top5_regions:
    print(f"\n--- {region_name} ---")
    seasonal_analysis(region_name, profile=profile)
    img_path = f"data/seasonal_{region_name.lower().replace(' ', '_')}.png"
    display(Image(img_path))
# Out:
# --- Beijing ---
#
# analyzing Beijing...
# graph saved to data/seasonal_beijing.png
#
# travel tips from groq:
# Spring: Pack layers for cooler mornings and warmer afternoons, and consider visiting popular cultural sites like the Forbidden City and Temple of Heaven during this season to avoid the crowds. Take advantage of the blooming flowers and greenery in Beijing's many parks and gardens.
#
# Summer: Be prepared for hot and humid weather by staying hydrated, wearing sunscreen, and taking breaks in air-conditioned museums like the National Museum of China or the Palace Museum. Explore Beijing's historic hutongs and traditional alleys, which offer a glimpse into the city's rich cultural heritage.
#
# Autumn: Enjoy the comfortable temperatures and vibrant foliage in Beijing's parks and gardens, and visit the Summer Palace, a UNESCO World Heritage Site, during this season. Take a stroll along the Qinhuangdao Street, which offers a mix of traditional and modern architecture, and explore the city's many cultural attractions like the Confucius Temple.
#
# Winter: Dress warmly, including a heavy coat, gloves, and scarf, as temperatures can drop below freezing, and consider visiting indoor cultural attractions like the Capital Museum or the Beijing Museum of Natural History. Take a tour of the city's historic sites, such as the Ming Tombs, which are less crowded during this time, and enjoy the city's festive atmosphere, including traditional winter festivals and decorations.
# --- Shanghai ---
#
# analyzing Shanghai...
# graph saved to data/seasonal_shanghai.png
#
# travel tips from groq:
# Spring: Visit Shanghai in spring to enjoy mild temperatures and explore the city's cultural attractions, such as the Shanghai Museum and Jing'an Temple, without the crowds. Consider purchasing a Shanghai Public Transportation Card for easy navigation.
#
# Summer: Summer is peak tourist season, so expect large crowds and long lines at popular destinations like the Bund and Oriental Pearl Tower, and be sure to stay hydrated and bring sunscreen. Take advantage of the city's extensive metro system to avoid traffic congestion.
#
# Autumn: Autumn is an ideal time to explore Shanghai's outdoor spaces, such as the Huangpu River waterfront and Fuxing Park, with comfortable temperatures and vibrant fall foliage. Consider visiting the Shanghai Grand Theatre to catch a performance of traditional Chinese opera or ballet.
#
# Winter: Shanghai can be chilly in the winter, so pack warm clothing and consider visiting indoor attractions like the Shanghai Science and Technology Museum or the Propaganda Poster Art Centre. Take a stroll along the beautifully lit Bund at night to enjoy the city's festive atmosphere.
# --- Xian ---
#
# analyzing Xian...
# graph saved to data/seasonal_xian.png
#
# travel tips from groq:
# Spring: Visit Xian in spring to enjoy mild temperatures, ideal for exploring the Terracotta Warriors and other outdoor historical sites without the summer crowds. Be sure to pack layers for cooler mornings and evenings.
#
# Summer: Summer is peak tourist season in Xian, so book accommodations and popular attractions like the Ancient City Wall and Muslim Quarter in advance to avoid long wait times. Don't forget to stay hydrated and bring sunscreen to protect against the heat.
#
# Autumn: Autumn is a great time to visit Xian's many museums, such as the Shaanxi History Museum, as the cooler temperatures make for a more comfortable indoor experience. Take a stroll along the Ancient City Wall and enjoy the fall foliage.
#
# Winter: If visiting Xian in winter, consider purchasing a warm hat and gloves as temperatures can drop significantly, and prioritize indoor attractions like the Xian Museum and local teahouses. Many historical sites may have limited hours or be closed due to cold weather, so plan accordingly.
# --- Hangzhou ---
#
# analyzing Hangzhou...
# graph saved to data/seasonal_hangzhou.png
#
# travel tips from groq:
# Spring: Visit the Lingyin Temple and Xixi Wetland to experience Hangzhou's cultural and natural heritage, and take a stroll along the West Lake to enjoy the scenic views. Pack layers for cooler mornings and evenings, with daytime temperatures around 17.0°C.
#
# Summer: Explore the city's museums, such as the Zhejiang Provincial Museum, to learn about Hangzhou's history and culture while escaping the heat, and stay hydrated by drinking plenty of water. Wear lightweight and breathable clothing to cope with the high temperatures of 27.7°C.
#
# Autumn: Wander through the historic Qinghefang Ancient Street to discover traditional shops and tea houses, and take a boat ride on the West Lake to admire the autumn foliage, with comfortable temperatures around 18.7°C. Book accommodations in advance to avoid peak season crowds.
#
# Winter: Visit the Hangzhou Museum to learn about the city's cultural and historical significance, and explore the scenic areas around the West Lake, which are less crowded during the winter months, with average temperatures of 7.2°C. Bring warm clothing, including a coat and gloves, to stay warm during outdoor explorations.
# --- Tibet ---
#
# analyzing Tibet...
# graph saved to data/seasonal_tibet.png
#
# travel tips from groq:
# Spring: As a solo traveller, visit Lhasa in spring to explore the Potala Palace and Jokhang Temple, two iconic cultural and historical sites, with mild weather averaging 7.9°C. Pack layers for temperature fluctuations during this season.
#
# Summer: Summer is peak tourist season, so book accommodations and tours in advance to ensure availability, and take advantage of the warmest weather to explore Lhasa's city streets and surrounding cultural attractions. Don't miss the Shoton Festival, a significant cultural event in Tibetan culture.
#
# Autumn: With comfortable temperatures averaging 12.4°C, autumn is an ideal time to visit the Ganden Monastery and other historical sites on the outskirts of Lhasa, and the city's scenic valleys are particularly beautiful during this season. Consider taking a guided city tour to learn more about Tibetan history and culture.
#
# Winter: If travelling solo to Lhasa in winter, consider joining a group tour to reduce costs and increase safety, as some attractions may be closed due to cold weather, and temperatures can drop to around 2.3°C. Pack warm clothing, including a down jacket and thermal layers, to stay warm while exploring the city's cultural and historical sites.

# %%
#DashBoard Export

# Cell 6 - Dashboard data
from WorldExplorer.country_dashboard_data import country_dashboard_data

data = country_dashboard_data(profile=profile)

print("\nstats for your profile:")
print(data["stats"][["region", "attraction_count", "avg_rating", "avg_cost_night", "budget_level"]])

print("\nmust-sees and hidden gems:")
print(data["mustsees"])
# Out:
# gathering dashboard data...
#   country: China
#   scraping Beijing...
# scraping data for Beijing...
#   scraping Shanghai...
# scraping data for Shanghai...
#   scraping Yunnan...
# scraping data for Yunnan...
#   scraping Sichuan...
# scraping data for Sichuan...
#   scraping Guilin...
# scraping data for Guilin...
#   scraping Hainan...
# scraping data for Hainan...
#   scraping Xian...
# scraping data for Xian...
#   scraping Tibet...
# scraping data for Tibet...
#   scraping Zhangjiajie...
# scraping data for Zhangjiajie...
#   scraping Hangzhou...
# scraping data for Hangzhou...
#   filtering for: ['culture_history', 'citytrip']
#   relevant regions: ['Beijing', 'Shanghai', 'Yunnan', 'Xian', 'Tibet', 'Hangzhou']
#   quality check passed for attractions (193 rows)
#   quality check passed for budget (6 rows)
#   quality check passed for must-sees (16 rows)
#   saved data/dashboard_attractions.csv (193 rows)
#   saved data/dashboard_budget.csv (6 rows)
#   saved data/dashboard_mustsees.csv (16 rows)
#   saved data/dashboard_stats.csv (6 rows)
#   saved to data/worldexplorer.db
#
# all exports done!
# files saved:
#   data/dashboard_attractions.csv
#   data/dashboard_budget.csv
#   data/dashboard_mustsees.csv
#   data/dashboard_stats.csv
#   data/worldexplorer.db
#
# stats for your profile:
#      region  attraction_count  avg_rating  avg_cost_night budget_level
# 0   Beijing                28         3.9              80    mid_range
# 1  Shanghai                29         4.0             120       luxury
# 2    Yunnan                23         2.8              30   backpacker
# 3      Xian                29         3.2              55    mid_range
# 4     Tibet                 7         4.7              60    mid_range
# 5  Hangzhou                27         2.8              65    mid_range
#
# must-sees and hidden gems:
#       region                           name        type  \
# 0   Shanghai                  Art galleries  hidden gem
# 1   Shanghai              Classical Gardens  hidden gem
# 2   Shanghai      Early Modern Architecture  hidden gem
# 3   Shanghai                        Museums  hidden gem
# 4   Shanghai                Performing Arts  hidden gem
# 5   Shanghai                    Skyscrapers  hidden gem
# 6   Shanghai                        Temples  hidden gem
# 7   Shanghai                    Water towns  hidden gem
# 8     Yunnan                    Itineraries  hidden gem
# 9       Xian                  Central Xi'an  hidden gem
# 10      Xian                  Greater Xi'an  hidden gem
# 11  Hangzhou            West Lake (西湖Xī Hú)  hidden gem
# 12  Hangzhou  Temples, pagodas and churches  hidden gem
# 13  Hangzhou       Gardens, forests, nature  hidden gem
# 14  Hangzhou                    Other sites  hidden gem
# 15  Hangzhou                       Liangzhu  hidden gem
#
#                                                  tags
# 0                  citytrip, gastronomy, wellness_spa
# 1                  citytrip, gastronomy, wellness_spa
# 2                  citytrip, gastronomy, wellness_spa
# 3                  citytrip, gastronomy, wellness_spa
# 4                  citytrip, gastronomy, wellness_spa
# 5                  citytrip, gastronomy, wellness_spa
# 6                  citytrip, gastronomy, wellness_spa
# 7                  citytrip, gastronomy, wellness_spa
# 8   nature_wildlife, adventure, culture_history, b...
# 9                         culture_history, gastronomy
# 10                        culture_history, gastronomy
# 11     wellness_spa, nature_wildlife, culture_history
# 12     wellness_spa, nature_wildlife, culture_history
# 13     wellness_spa, nature_wildlife, culture_history
# 14     wellness_spa, nature_wildlife, culture_history
# 15     wellness_spa, nature_wildlife, culture_history

# %% [markdown]
# ## What was exported
# All data has been saved to the `data/` folder:
# - `top5_destinations.csv` — your personalised top 5
# - `current_profile.csv` — your travel profile
# - `dashboard_attractions.csv` — filtered attractions
# - `dashboard_budget.csv` — budget info per region
# - `dashboard_mustsees.csv` — must-sees and hidden gems
# - `dashboard_stats.csv` — stats per region
# - `worldexplorer.db` — SQLite database for Node-RED
# - `attractions_map.html` — interactive map
# - `seasonal_*.png` — climate graphs per region
